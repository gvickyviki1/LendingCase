# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('loan.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501  1296599    5000       5000         4975.0            36 months
# 1  1077430  1314167    2500       2500         2500.0            60 months
# 2  1077175  1313524    2400       2400         2400.0            36 months
# 3  1076863  1277178    10000      10000        10000.0           36 months
# 4  1075358  1311748    3000       3000         3000.0            60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0  10.65%   162.87       B     B2        ... NaN
# 1  15.27%   59.83        C     C4        ... NaN
# 2  15.96%   84.33        C     C5        ... NaN
# 3  13.49%   339.31       C     C1        ... NaN
# 4  12.69%   67.79        B     B5        ... NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0 NaN                NaN            NaN                0.0
# 1 NaN                NaN            NaN                0.0
# ...

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 48 columns):
# id                         39717 non-null int64
# member_id                  39717 non-null int64
# loan_amnt                  39717 non-null int64
# funded_amnt                39717 non-null int64
# funded_amnt_inv            39717 non-null float64
# term                       39717 non-null int64
# int_rate                   39717 non-null float64
# installment                39717 non-null float64
# grade                      39717 non-null object
# sub_grade                  39717 non-null object
# emp_title                  37258 non-null object
# emp_length                 38642 non-null float64
# home_ownership             39717 non-null object
# annual_inc                 39717 non-null float64
# verification_status        39717 non-null object
# issue_d                    39717 non-null object
# loan_status                39717 non-null object
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05  7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04  500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05  5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000  9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count  39717.000000     39717.000000  3.971700e+04  39717.000000
# mean   10397.448868     324.561922    6.896893e+04  13.315130
# std    7128.450439      208.874874    6.379377e+04  6.678594
# min    0.000000         15.690000     4.000000e+03  0.000000
# 25%    5000.000000      167.020000    4.040400e+04  8.170000
# ...

# %% [markdown]
# # Data Cleaning
#
# 1. Remove completely null columns
# 2. Remove columns having only one value in them

# %%
completely_null = df.isnull().sum()[df.isnull().sum() == 39717].to_dict()
completely_null_key = list(completely_null.keys())
completely_null_key
# Out:
# ['mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
# ...

# %%
df.drop(columns =completely_null_key, inplace = True)

# %%
df.isnull().sum()[(df.isnull().sum() > 0)]*100/(len(df))
# Out:
# emp_title                     6.191303
# emp_length                    2.706650
# desc                          32.580507
# title                         0.027696
# mths_since_last_delinq        64.662487
# mths_since_last_record        92.985372
# revol_util                    0.125891
# last_pymnt_d                  0.178765
# next_pymnt_d                  97.129693
# last_credit_pull_d            0.005036
# collections_12_mths_ex_med    0.140998
# chargeoff_within_12_mths      0.140998
# pub_rec_bankruptcies          1.754916
# tax_liens                     0.098195
# dtype: float64

# %%
only_one_value = df.nunique()[df.nunique() == 1].to_dict()
only_one_value_columns = list(only_one_value.keys())
only_one_value_columns
# Out:
# ['pymnt_plan',
#  'initial_list_status',
#  'collections_12_mths_ex_med',
#  'policy_code',
#  'application_type',
#  'acc_now_delinq',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'tax_liens']

# %%
df.drop(columns =only_one_value_columns, inplace = True)

# %%
df.isnull().sum()[(df.isnull().sum() > 0)]*100/(len(df))
# Out:
# emp_title                 6.191303
# emp_length                2.706650
# desc                      32.580507
# title                     0.027696
# mths_since_last_delinq    64.662487
# mths_since_last_record    92.985372
# revol_util                0.125891
# last_pymnt_d              0.178765
# next_pymnt_d              97.129693
# last_credit_pull_d        0.005036
# pub_rec_bankruptcies      1.754916
# dtype: float64

# %%
df.shape
# Out:
# (39717, 48)

# %%
df['term'] = df['term'].apply(lambda x: int(x.strip().split(' ')[0]))

# %%
df['int_rate'] = df['int_rate'].apply(lambda x: float(str(x).strip().split('%')[0]))
df['revol_util'] = df['revol_util'].apply(lambda x: float(str(x).strip().split('%')[0]))
df['emp_length'] = df['emp_length'].apply(lambda x: float(str(str(str(x).strip().split('year')[0]).split('+')[0]).strip().split('<')[-1].strip()))

# %%
df1 = df[df['loan_status'].isin(['Fully Paid', 'Charged Off'])]
df1.shape
# Out:
# (38577, 48)

# %%
df1.isnull().sum()[(df1.isnull().sum() > 0)]*100/(len(df1))
# Out:
# emp_title                 6.185033
# emp_length                2.677761
# desc                      32.472717
# title                     0.028514
# mths_since_last_delinq    64.559193
# mths_since_last_record    92.897322
# revol_util                0.129611
# last_pymnt_d              0.184047
# next_pymnt_d              100.000000
# last_credit_pull_d        0.005184
# pub_rec_bankruptcies      1.806776
# dtype: float64

# %%
df1.drop(columns=['next_pymnt_d','mths_since_last_delinq','mths_since_last_record'], inplace =True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4097: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.isnull().sum()[(df1.isnull().sum() > 0)]*100/(len(df1))
# Out:
# emp_title               6.185033
# emp_length              2.677761
# desc                    32.472717
# title                   0.028514
# revol_util              0.129611
# last_pymnt_d            0.184047
# last_credit_pull_d      0.005184
# pub_rec_bankruptcies    1.806776
# dtype: float64

# %%
df1['term'].value_counts()
# Out:
# 36    29096
# 60    9481
# Name: term, dtype: int64

# %%
#df1.to_csv('loans_1.csv',index=False)

# %% [markdown]
# Columns of least/not important

# %%
no_important = ['delinq_2yrs','earliest_cr_line','inq_last_6mths','open_acc','pub_rec','revol_bal','revol_util','total_acc','out_prncp','out_prncp_inv']

# %%
df1.drop(columns=no_important, inplace=True)

# %%
df1.isnull().sum()[(df1.isnull().sum() > 0)]*100/(len(df1))
# Out:
# emp_title               6.185033
# emp_length              2.677761
# desc                    32.472717
# title                   0.028514
# last_pymnt_d            0.184047
# last_credit_pull_d      0.005184
# pub_rec_bankruptcies    1.806776
# dtype: float64

# %% [markdown]
# # Univariate Analysis

# %%
default_rate_df = df1.groupby(['term','loan_status']).size().reset_index()
default_rate_df.rename(columns={0:'Count'}, inplace=True)
default_rate_df['percent'] = default_rate_df['Count']*100/len(df1)
default_rate_df
# Out:
#    term  loan_status  Count    percent
# 0  36    Charged Off  3227   8.365088
# 1  36    Fully Paid   25869  67.058092
# 2  60    Charged Off  2400   6.221324
# 3  60    Fully Paid   7081   18.355497

# %%
sns.kdeplot(df1['funded_amnt'])

# %%
sns.kdeplot(df1['loan_amnt'])

# %%
sns.kdeplot(df1['funded_amnt_inv'])

# %%
sns.kdeplot(df1['int_rate'])

# %%
grp = ['loan_amnt','int_rate','funded_amnt','funded_amnt_inv']
plt.figure(figsize=(20, 12))
for n, x in enumerate(grp):
    plt.subplot(2,2,n+1)
    sns.distplot(df1[x])

# %%
plt.figure(figsize=(7, 7))
plt.title('Box plot of Loan amount')
sns.boxplot(y='loan_amnt',data=df1)
# Out:
# Text(0.5, 1.0, 'Box plot of Loan amount')

# %% [markdown]
# # Bivariate Analysis

# %%
Verfication_df = df1.groupby(['verification_status','loan_status']).size().reset_index()
Verfication_df.rename(columns={0:'Count'}, inplace=True)
Verfication_df['percent'] = Verfication_df['Count']*100/len(df1)
Verfication_df
# Out:
#   verification_status  loan_status  Count    percent
# 0  Not Verified        Charged Off  2142   5.552531
# 1  Not Verified        Fully Paid   14552  37.721959
# 2  Source Verified     Charged Off  1434   3.717241
# 3  Source Verified     Fully Paid   8243   21.367654
# 4  Verified            Charged Off  2051   5.316639
# 5  Verified            Fully Paid   10155  26.323975

# %%
Verfication_df = df1.groupby(['verification_status','loan_status']).size()

# %%
Verfication_df.plot.pie(y='percent')

# %%
Verfication_df = df1.groupby(['verification_status','loan_status']).size().reset_index()
Verfication_df.rename(columns={0:'Count'}, inplace=True)
Verfication_df['percent'] = Verfication_df['Count']*100/len(df1)
Verfication_df
# Out:
#   verification_status  loan_status  Count    percent
# 0  Not Verified        Charged Off  2142   5.552531
# 1  Not Verified        Fully Paid   14552  37.721959
# 2  Source Verified     Charged Off  1434   3.717241
# 3  Source Verified     Fully Paid   8243   21.367654
# 4  Verified            Charged Off  2051   5.316639
# 5  Verified            Fully Paid   10155  26.323975

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='verification_status', y = 'percent',hue='loan_status', data = Verfication_df)
plt.title('Percentage of paid and default based on grade')
plt.show()
# Out:
# Text(0.5, 1.0, 'Percentage of paid and default based on grade')

# %%
Grade_df = df1.groupby(['grade','loan_status']).size()
Grade_df.plot.pie(y='percent')

# %%
Grade_df = df1.groupby(['grade','loan_status']).size().reset_index()
Grade_df.rename(columns={0:'Count'}, inplace=True)
Grade_df['percent'] = Grade_df['Count']*100/len(df1)
Grade_df
# Out:
#    grade  loan_status  Count    percent
# 0   A     Charged Off  602    1.560515
# 1   A     Fully Paid   9443   24.478316
# 2   B     Charged Off  1425   3.693911
# 3   B     Fully Paid   10250  26.570236
# 4   C     Charged Off  1347   3.491718
# 5   C     Fully Paid   6487   16.815719
# 6   D     Charged Off  1118   2.898100
# 7   D     Fully Paid   3967   10.283329
# 8   E     Charged Off  715    1.853436
# 9   E     Fully Paid   1948   5.049641
# 10  F     Charged Off  319    0.826918
# 11  F     Fully Paid   657    1.703087
# 12  G     Charged Off  101    0.261814
# 13  G     Fully Paid   198    0.513259

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='grade', y = 'percent',hue='loan_status', data = Grade_df[Grade_df['loan_status'] =='Charged Off'])
plt.title('Percentage of paid and default based on grade')
plt.show()
# Out:
# Text(0.5, 1.0, 'Percentage of paid and default based on grade')

# %%
Purpose_df = df1.groupby(['purpose','loan_status']).size().reset_index()
Purpose_df.rename(columns={0:'Count'}, inplace=True)
Purpose_df['percent'] = Purpose_df['Count']*100/len(df1)
Purpose_df
# Out:
#                purpose  loan_status  Count    percent
# 0   car                 Charged Off  160    0.414755
# 1   car                 Fully Paid   1339   3.470980
# 2   credit_card         Charged Off  542    1.404982
# 3   credit_card         Fully Paid   4485   11.626098
# 4   debt_consolidation  Charged Off  2767   7.172668
# 5   debt_consolidation  Fully Paid   15288  39.629831
# 6   educational         Charged Off  56     0.145164
# 7   educational         Fully Paid   269    0.697307
# 8   home_improvement    Charged Off  347    0.899500
# 9   home_improvement    Fully Paid   2528   6.553128
# 10  house               Charged Off  59     0.152941
# 11  house               Fully Paid   308    0.798403
# 12  major_purchase      Charged Off  222    0.575472
# 13  major_purchase      Fully Paid   1928   4.997797
# 14  medical             Charged Off  106    0.274775
# 15  medical             Fully Paid   575    1.490525
# 16  moving              Charged Off  92     0.238484
# ...

# %%
plt.figure(figsize=(20, 5))
sns.barplot(x='purpose', y = 'percent',hue='loan_status', data = Purpose_df[Purpose_df['loan_status'] =='Charged Off'])
plt.title('Percentage of default based on purpose')
plt.show()
# Out:
# Text(0.5, 1.0, 'Percentage of default based on purpose')

# %%
home_ownership_df = df1.groupby(['home_ownership','loan_status']).size().reset_index()
home_ownership_df.rename(columns={0:'Count'}, inplace=True)
home_ownership_df['percent'] = home_ownership_df['Count']*100/len(df1)
home_ownership_df
# Out:
#   home_ownership  loan_status  Count    percent
# 0  MORTGAGE       Charged Off  2327   6.032092
# 1  MORTGAGE       Fully Paid   14694  38.090054
# 2  NONE           Fully Paid   3      0.007777
# 3  OTHER          Charged Off  18     0.046660
# 4  OTHER          Fully Paid   80     0.207377
# 5  OWN            Charged Off  443    1.148353
# 6  OWN            Fully Paid   2532   6.563496
# 7  RENT           Charged Off  2839   7.359307
# 8  RENT           Fully Paid   15641  40.544884

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='home_ownership', y = 'percent',hue='loan_status', data = home_ownership_df)
plt.title('Percentage of home owner and loan status')
plt.show()
# Out:
# Text(0.5, 1.0, 'Percentage of home owner and loan status')

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(hue='emp_length', x = 'loan_amnt',y='funded_amnt', data= df1)
plt.title('Distribution of Employee length and loan amount')
plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of Employee length and loan amount')

# %%
#sns.pairplot(df1,hue='loan_status',palette='coolwarm')

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(),annot=True)
plt.title('Correlation Map')
# Out:
# Text(0.5, 1, 'Correlation Map')

# %%
pub_rec_bankruptcies_df = df1.groupby(['pub_rec_bankruptcies','loan_status']).size().reset_index()
pub_rec_bankruptcies_df.rename(columns={0:'Count'}, inplace=True)
pub_rec_bankruptcies_df['percent'] = pub_rec_bankruptcies_df['Count']*100/len(df1)
pub_rec_bankruptcies_df
# Out:
#    pub_rec_bankruptcies  loan_status  Count    percent
# 0  0.0                   Charged Off  5141   13.326594
# 1  0.0                   Fully Paid   31097  80.610208
# 2  1.0                   Charged Off  366    0.948752
# 3  1.0                   Fully Paid   1271   3.294709
# 4  2.0                   Charged Off  2      0.005184
# 5  2.0                   Fully Paid   3      0.007777

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='pub_rec_bankruptcies', y = 'percent',hue='loan_status', data = pub_rec_bankruptcies_df)
plt.title('Percentage of paid and default based on purpose')
plt.show()
# Out:
# Text(0.5, 1.0, 'Percentage of paid and default based on purpose')
